# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'C:\Users\LENOVO\Downloads\onlinefoods.csv')
df
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 0     20  Female         Single    Student       No Income
# 1     24  Female         Single    Student  Below Rs.10000
# 2     22    Male         Single    Student  Below Rs.10000
# 3     22  Female         Single    Student       No Income
# 4     22    Male         Single    Student  Below Rs.10000
# ..   ...     ...            ...        ...             ...
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0                Post Graduate            4   12.9766    77.5993    560001
# 1                     Graduate            3   12.9770    77.5773    560009
# ...

# %%
#Show first 5 rows
df.head()
# Out:
#    Age  Gender Marital Status Occupation  Monthly Income  \
# 0   20  Female         Single    Student       No Income
# 1   24  Female         Single    Student  Below Rs.10000
# 2   22    Male         Single    Student  Below Rs.10000
# 3   22  Female         Single    Student       No Income
# 4   22    Male         Single    Student  Below Rs.10000
#
#   Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 0              Post Graduate            4   12.9766    77.5993    560001
# 1                   Graduate            3   12.9770    77.5773    560009
# 2              Post Graduate            3   12.9551    77.6593    560017
# 3                   Graduate            6   12.9473    77.5616    560019
# 4              Post Graduate            4   12.9850    77.5533    560010
#
#   Output   Feedback Unnamed: 12
# 0    Yes   Positive         Yes
# 1    Yes   Positive         Yes
# 2    Yes  Negative          Yes
# 3    Yes   Positive         Yes
# ...

# %%
#Show the last 5 rows
df.tail()
# Out:
#      Age  Gender Marital Status Occupation  Monthly Income  \
# 383   23  Female         Single    Student       No Income
# 384   23  Female         Single    Student       No Income
# 385   22  Female         Single    Student       No Income
# 386   23    Male         Single    Student  Below Rs.10000
# 387   23    Male         Single    Student       No Income
#
#     Educational Qualifications  Family size  latitude  longitude  Pin code  \
# 383              Post Graduate            2   12.9766    77.5993    560001
# 384              Post Graduate            4   12.9854    77.7081    560048
# 385              Post Graduate            5   12.9850    77.5533    560010
# 386              Post Graduate            2   12.9770    77.5773    560009
# 387              Post Graduate            5   12.8988    77.5764    560078
#
#     Output  Feedback Unnamed: 12
# 383    Yes  Positive         Yes
# 384    Yes  Positive         Yes
# 385    Yes  Positive         Yes
# ...

# %%
#How many columns and rows are there in the dataset?
df.shape
# Out:
# (388, 13)

# %%
#Show statistical information of numeric columns
df.describe()
# Out:
#               Age  Family size    latitude   longitude       Pin code
# count  388.000000   388.000000  388.000000  388.000000     388.000000
# mean    24.628866     3.280928   12.972058   77.600160  560040.113402
# std      2.975593     1.351025    0.044489    0.051354      31.399609
# min     18.000000     1.000000   12.865200   77.484200  560001.000000
# 25%     23.000000     2.000000   12.936900   77.565275  560010.750000
# 50%     24.000000     3.000000   12.977000   77.592100  560033.500000
# 75%     26.000000     4.000000   12.997025   77.630900  560068.000000
# max     33.000000     6.000000   13.102000   77.758200  560109.000000

# %%
#Show column names
df.columns
# Out:
# Index(['Age', 'Gender', 'Marital Status', 'Occupation', 'Monthly Income',
#        'Educational Qualifications', 'Family size', 'latitude', 'longitude',
#        'Pin code', 'Output', 'Feedback', 'Unnamed: 12'],
#       dtype='object')

# %%
#How many unique values are there in each column?
df.nunique()
# Out:
# Age                           16
# Gender                         2
# Marital Status                 3
# Occupation                     4
# Monthly Income                 5
# Educational Qualifications     5
# Family size                    6
# latitude                      77
# longitude                     76
# Pin code                      77
# Output                         2
# Feedback                       2
# Unnamed: 12                    2
# dtype: int64

# %%
#How many null values are there in total in each column?
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Marital Status                0
# Occupation                    0
# Monthly Income                0
# Educational Qualifications    0
# Family size                   0
# latitude                      0
# longitude                     0
# Pin code                      0
# Output                        0
# Feedback                      0
# Unnamed: 12                   0
# dtype: int64

# %%
#What is the distribution of customers' ages in the dataset?
df['Age'].value_counts().sort_values(ascending=True)
# Out:
# Age
# 18     1
# 33     1
# 19     4
# 31     8
# 20     9
# 30     9
# 29    14
# 28    15
# 32    16
# 27    21
# 21    23
# 26    35
# 24    50
# 25    52
# 22    57
# 23    73
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 5))
plt.hist(df['Age'], bins=16, color='magenta', edgecolor='black')
plt.title('Distribution of Customers\' Ages')
plt.xlabel('Age')
plt.ylabel('Number of Customers')
plt.xticks(range(int(df['Age'].min()), int(df['Age'].max()) + 1))
plt.show()

# %%
#How many male and female customers are there in the dataset? 
df['Gender'].value_counts()
# Out:
# Gender
# Male      222
# Female    166
# Name: count, dtype: int64

# %%
#What are the different marital statuses represented in the dataset, and what is their distribution?
df['Marital Status'].value_counts()
# Out:
# Marital Status
# Single               268
# Married              108
# Prefer not to say     12
# Name: count, dtype: int64

# %%
#What are the most common occupations among the customers?
df['Occupation'].value_counts().head()
# Out:
# Occupation
# Student           207
# Employee          118
# Self Employeed     54
# House wife          9
# Name: count, dtype: int64

# %%
#How many customers fall into each category of educational qualifications?
df['Educational Qualifications'].value_counts()
# Out:
# Educational Qualifications
# Graduate         177
# Post Graduate    174
# Ph.D              23
# School            12
# Uneducated         2
# Name: count, dtype: int64

# %%
#What is the average family size of customers?
df['Family size'].mean()
# Out:
# 3.2809278350515463

# %%
#What are the most common pin codes among customers?
df['Pin code'].value_counts().head()
# Out:
# Pin code
# 560009    36
# 560038    16
# 560010    14
# 560076    12
# 560095    11
# Name: count, dtype: int64

# %%
#What percentage of customers provided feedback after receiving their orders?
provided_feedback = df['Feedback'].notnull().sum()
total_customer = len(df)
feedback_percentage = (provided_feedback/total_customer)*100
print('{} %'. format(feedback_percentage))
# Out:
# 100.0 %

# %%
#Use a pie chart to illustrate the proportion of customers in each marital status category. 
plt.figure(figsize=(5,5))
df['Marital Status'].value_counts().plot(kind='pie', autopct='%.0f%%', colors=sns.color_palette('Accent'))
plt.title('Proportion of Marital Status')
plt.ylabel('') 
plt.show()

# %%
#Generate a bar chart to display the count of customers in each educational qualification category. 
plt.bar(df['Educational Qualifications'].value_counts().index, df['Educational Qualifications'].value_counts().values, color='coral', edgecolor='white')
plt.title('Count of Customers by Educational Qualification')
plt.xlabel('Educational Qualification')
plt.ylabel('Number of Customers')
plt.xticks(rotation=45)
plt.show()

# %%
#Generate a heatmap to visualize the distribution of order statuses based on age and gender. 
pivot_table = df.pivot_table(index='Age', columns='Gender', values='Output', aggfunc='count')
plt.figure(figsize=(10, 5))
sns.heatmap(pivot_table, annot=True, cmap='coolwarm', linewidths=.5)
plt.title('Distribution of Order Statuses Based on Age and Gender')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %%
#Generate a bar chart to display the top N most common pin codes among customers. 
plt.bar(df['Pin code'].value_counts().head().index.astype(str), df['Pin code'].value_counts().head().values, color='crimson', edgecolor='black')
plt.title('Top 5 Most Common Pin Codes Among Customers')
plt.xlabel('Pin Codes')
plt.ylabel('Number of Customers')
plt.xticks(rotation=0)
plt.show()

# %%
#Create a heatmap of the correlation matrix to visualize the correlations between different numerical attributes. 
df2 = df.select_dtypes(include='number')
corr_mat = df2.corr()
plt.figure(figsize=(8, 5)) 
sns.heatmap(corr_mat, annot=True, fmt='.2f', cmap='inferno', linewidths=.5)
plt.xlabel('Attributes')
plt.ylabel('Attributes')
plt.title('Correlation Matrix Heatmap')
plt.show()
