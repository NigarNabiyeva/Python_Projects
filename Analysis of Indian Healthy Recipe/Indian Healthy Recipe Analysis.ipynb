# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Read data
df = pd.read_excel(r'C:\Users\LENOVO\Downloads\IndianHealthyRecipe.xlsx')
df
# Out:
#                                      Dish Name  \
# 0                            Pistachio chicken
# 1                             Tangy Fried Okra
# 2                        Healthy Chicken Korma
# 3                            Brown Lentil Dhal
# 4                           Thari Wala Chicken
# ..                                         ...
# 144  Vegan Wild Rice, Cumin & Chickpea Burgers
# 145                            Vegetable Pilau
# 146                  Watermelon and Feta Chaat
# 147                    Zambezi Baked Sea Bream
# 148                                      Zhoug
#
#                                   Description   Spice     Prep Time   Views  \
# 0    Mild chicken in a creamy pistachio sauce    mild  Prep 10 mins   11604
# 1                         Bhindi with Amchoor  medium  Prep 10 mins   49899
# 2              Chicken in Creamy Almond Sauce    mild  Prep 10 mins  115569
# 3                        Sabut Masoor di Dhal  medium  Prep 10 mins  146798
# ...

# %%
#Look first 5 row of data. 
df.head()
# Out:
#                Dish Name                               Description   Spice  \
# 0      Pistachio chicken  Mild chicken in a creamy pistachio sauce    mild
# 1       Tangy Fried Okra                       Bhindi with Amchoor  medium
# 2  Healthy Chicken Korma            Chicken in Creamy Almond Sauce    mild
# 3      Brown Lentil Dhal                      Sabut Masoor di Dhal  medium
# 4     Thari Wala Chicken                     Healthy Chicken Curry  medium
#
#       Prep Time   Views  Rating  Number of Votes  Serves       Dietary Info  \
# 0  Prep 10 mins   11604     4.1             18.0     4.0  ['CONTAINS-NUTS']
# 1  Prep 10 mins   49899     4.6             35.0     4.0     ['VEGETARIAN']
# 2  Prep 10 mins  115569     3.6            163.0     4.0  ['CONTAINS-NUTS']
# 3  Prep 10 mins  146798     3.7             87.0     4.0     ['VEGETARIAN']
# 4  Prep 10 mins  262696     3.5            343.0     4.0   ['LACTOSE-FREE']
#
# ...

# %%
#Show the last 5 rows
df.tail()
# Out:
#                                      Dish Name  \
# 144  Vegan Wild Rice, Cumin & Chickpea Burgers
# 145                            Vegetable Pilau
# 146                  Watermelon and Feta Chaat
# 147                    Zambezi Baked Sea Bream
# 148                                      Zhoug
#
#                                 Description   Spice     Prep Time  Views  \
# 144                      Channa Chaul Tikki  medium  Prep 10 mins  12641
# 145                    Mixed Vegetable Rice  medium  Prep 10 mins  69937
# 146  Indian Style Watermelon and Feta Salad  medium  Prep 40 mins  16652
# 147                       Shama with relish  medium   Prep 5 mins  11808
# 148            Middle Eastern Coriander Dip  medium   Prep 5 mins  67834
#
#      Rating  Number of Votes  Serves      Dietary Info Cook Time  \
# 144     4.2              9.0     4.0    ['VEGETARIAN']   15 mins
# 145     4.0             15.0     4.0    ['VEGETARIAN']   20 mins
# ...

# %%
#How many unique values are there in each column?
df.nunique()
# Out:
# Dish Name          149
# Description        144
# Spice                4
# Prep Time           12
# Views              149
# Rating              22
# Number of Votes     82
# Serves               6
# Dietary Info        10
# Cook Time           13
# Ingredients        148
# Instructions       148
# dtype: int64

# %%
#How many columns and rows are there in the dataset?
df.shape
# Out:
# (149, 12)

# %%
#Show statistical information of numeric columns
df.describe()
# Out:
#                Views      Rating  Number of Votes      Serves
# count     149.000000  149.000000       147.000000  146.000000
# mean    72516.563758    3.833557        66.761905    4.445205
# std     82521.553789    0.561442       128.797991    1.399659
# min      3981.000000    0.000000         0.000000    1.000000
# 25%     28613.000000    3.500000        16.000000    4.000000
# 50%     49854.000000    3.800000        29.000000    4.000000
# 75%     84817.000000    4.100000        68.000000    4.000000
# max    596269.000000    5.000000      1266.000000   12.000000

# %%
#Show column names
df.columns
# Out:
# Index(['Dish Name', 'Description', 'Spice', 'Prep Time', 'Views', 'Rating',
#        'Number of Votes', 'Serves', 'Dietary Info', 'Cook Time', 'Ingredients',
#        'Instructions'],
#       dtype='object')

# %%
#Is there duplicated dish name?
df['Dish Name'].duplicated().sum()
# Out:
# 0

# %%
#Show dish name which is get max views.
max_view=df['Views'].max()
df[df['Views']==max_view][['Dish Name', 'Views']]
# Out:
#        Dish Name   Views
# 71  Marrow Curry  596269

# %%
#Show dish name which is get max rating.
max_rating=df['Rating'].max()
df[df['Rating']==max_rating][['Dish Name', 'Rating']]
# Out:
#                                Dish Name  Rating
# 60   Kati Egg Roll with Basmati & Quinoa     5.0
# 92          Pitta Bread with Carom Seeds     5.0
# 95                       Power Salad Jar     5.0
# 127                 Spiced Pumpkin Seeds     5.0

# %%
#Find dish name that gives the least serves.
least_serves=df['Serves'].min()
df[df['Serves']==least_serves][['Dish Name', 'Serves']]
# Out:
#                          Dish Name  Serves
# 131  Spinach and Mushroom Omelette     1.0

# %%
#Check null values and deal with them.
df.isnull().sum()
# Out:
# Dish Name           0
# Description         0
# Spice               4
# Prep Time           1
# Views               0
# Rating              0
# Number of Votes     2
# Serves              3
# Dietary Info        0
# Cook Time          15
# Ingredients         0
# Instructions        0
# dtype: int64

# %%
df2= df.fillna(value="-")
df2.isnull().sum()
# Out:
# Dish Name          0
# Description        0
# Spice              0
# Prep Time          0
# Views              0
# Rating             0
# Number of Votes    0
# Serves             0
# Dietary Info       0
# Cook Time          0
# Ingredients        0
# Instructions       0
# dtype: int64

# %%
#Create a histogram to show the distribution of ratings for the dishes.
plt.figure(figsize=(8, 6))
sns.histplot(df['Rating'], bins=10, kde=True)
plt.title('Distribution of Ratings for Indian Healthy Recipes')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
#Create a bar chart to display the top 10 dishes based on the number of views.
top_views = df.nlargest(10, 'Views')
plt.figure(figsize=(8, 5))
sns.barplot(x='Views', y='Dish Name', data=top_views, color='magenta')
plt.title('Top 10 Dishes by Views')
plt.xlabel('Number of Views')
plt.ylabel('Dish Name')
plt.show()

# %%
#Create a heatmap of the correlation matrix to visualize the correlations between different numerical attributes. 
df3 = df.select_dtypes(include='number')
plt.figure(figsize=(8, 5))
correlation_matrix = df3.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
